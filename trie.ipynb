# %% [markdown]
# # Trie
#
# [Article on Trie. General Template and List of problems](https://leetcode.com/discuss/general-discussion/680706/article-on-trie-general-template-and-list-of-problems)
#
# * a tree-like data structure wherein all the nodes stores alphabetical values
# * ordered data structure in which every traversal down the branch retrieves a string or word

# %%
# https://leetcode.com/problems/stream-of-characters/discuss/320837/Standard-Python-Trie-Solution
class TrieNode():
    def __init__(self):
        self.children = {}
        self.isEnd = False

class Trie():
    def __init__(self):
        self.root =TrieNode()
    
    def insert(self, word):
        node = self.root
        for char in word:
            if char not in node.children:
                node.children[char] = TrieNode()
            node = node.children[char]
        node.isEnd = True
    
    def search(self, word):
        node = self.root
        for char in word:
            if char not in node.children:
                return False
            node = node.children[char]
        return node.isEnd

# %%
# 676. Implement Magic Dictionary

from string import ascii_lowercase

class TrieNode():
    def __init__(self, char):
        self.char = char
        self.children = {}
        self.isEnd = False

class MagicDictionary:

    def __init__(self):
        self.root =TrieNode("#")
        
    def insert(self, word):
        node = self.root
        for char in word:
            if char not in node.children:
                node.children[char] = TrieNode(char)
            node = node.children[char]
        node.isEnd = True

    def buildDict(self, dictionary: List[str]) -> None:
        for word in dictionary:
            self.insert(word)
    
    def found(self, word): # search word
        node = self.root
        for char in word:
            if char not in node.children:
                return False
            node = node.children[char]
        return node.isEnd
        

    def search(self, searchWord: str) -> bool:
        for i in range(len(searchWord)):
            ori_char = searchWord[i]
            for new_char in ascii_lowercase:
                if new_char == ori_char:
                    continue
                new_word = searchWord[:i] + new_char + searchWord[i+1:]
                if self.found(new_word):
                    return True
        return False

# %%
# 421. Maximum XOR of Two Numbers in an Array
# Bitwise Trie

class TrieNode():
    def __init__(self):
        self.val = 0 # end value
        self.children = {}

class Trie():
    def __init__(self, length):
        self.root = TrieNode()
        self.length = length # max length of all numbers
    
    def insert(self, num):
        node = self.root
        for shift in range(self.length, -1, -1):
            val = 1 if num & (1 << shift) else 0
            if val not in node.children:
                node.children[val] = TrieNode()
            node = node.children[val]
        node.val = num

class Solution:
    def findMaximumXOR(self, nums: List[int]) -> int:
        max_len = len(bin(max(nums))) - 2
        trie = Trie(max_len)

        for num in nums:
            trie.insert(num)

        res = 0
        for num in nums:
            node = trie.root
            for shift in range(max_len, -1, -1):
                val = 1 if num & (1 << shift) else 0
                if 1-val in node.children:
                    # try opposite bit first
                    node = node.children[1-val]
                else:
                    node = node.children[val]
            res = max(res, num ^ node.val)
        return res
